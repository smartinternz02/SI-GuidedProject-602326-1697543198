# %%
! pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\maheshteja\anaconda3\lib\site-packages (1.24.3)

# %%
! pip install pandas

# %%
! pip install scikit-learn

# %%
! pip install matplotlib

# %%
! pip install pickle-mixin

# %%
! pip install seaborn

# %%
!  pip install scale
# Out:
# Collecting scale
#   Downloading scale-1.1.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.10/dist-packages (from scale) (1.23.5)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from scale) (1.5.3)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scale) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scale) (1.2.2)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scale) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.10/dist-packages (from scale) (4.66.1)
# Requirement already satisfied: matplotlib>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from scale) (3.7.1)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from scale) (0.12.2)
# Collecting umap-learn (from scale)
#   Downloading umap-learn-0.5.4.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scanpy>=1.6.1 (from scale)
#   Downloading scanpy-1.9.6-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.2->scale) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->scale) (2023.3.post1)
# Collecting anndata>=0.7.4 (from scanpy>=1.6.1->scale)
#   Downloading anndata-0.10.3-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.10/dist-packages (from scanpy>=1.6.1->scale) (3.9.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy>=1.6.1->scale) (1.3.2)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy>=1.6.1->scale) (8.4.0)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from scanpy>=1.6.1->scale) (3.2)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from scanpy>=1.6.1->scale) (0.56.4)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy>=1.6.1->scale) (0.5.3)
# Collecting session-info (from scanpy>=1.6.1->scale)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.10/dist-packages (from scanpy>=1.6.1->scale) (0.14.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->scale) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->scale) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->scale) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->scale) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->scale) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->scale) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->scale) (2.1.0)
# Collecting pynndescent>=0.5 (from umap-learn->scale)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn->scale) (2021.10.0)
# Collecting array-api-compat (from anndata>=0.7.4->scanpy>=1.6.1->scale)
#   Downloading array_api_compat-1.4-py3-none-any.whl (29 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.7.4->scanpy>=1.6.1->scale) (1.1.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy>=1.6.1->scale) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy>=1.6.1->scale) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.2->scale) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->scale) (2.1.3)
# Collecting stdlib_list (from session-info->scanpy>=1.6.1->scale)
#   Downloading stdlib_list-0.9.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->scale) (1.3.0)
# Building wheels for collected packages: umap-learn, pynndescent, session-info
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.4-py3-none-any.whl size=86770 sha256=2fee424dad093e821bc79054eb6de360ad4d3d46439585df9ae4557e174da167
#   Stored in directory: /root/.cache/pip/wheels/fb/66/29/199acf5784d0f7b8add6d466175ab45506c96e386ed5dd0633
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=3aeb795ab73eed4f335f79a6634e3e3470855e72348b13e2b7e764513e80f5f5
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8026 sha256=fb793c131b383fc7b1a45871171a65626dbc76882603fe49a37681789540470a
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built umap-learn pynndescent session-info
# Installing collected packages: stdlib_list, array-api-compat, session-info, pynndescent, anndata, umap-learn, scanpy, scale
# Successfully installed anndata-0.10.3 array-api-compat-1.4 pynndescent-0.5.10 scale-1.1.2 scanpy-1.9.6 session-info-1.0.0 stdlib_list-0.9.0 umap-learn-0.5.4

# %%
! pip install Flask
# Out:
# Requirement already satisfied: Flask in /usr/local/lib/python3.10/dist-packages (2.2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask) (2.1.3)

# %%
! pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.11.0

# %%
 ! pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)

# %%
import pandas as pd

import numpy as np

import pickle

import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

import sklearn

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import RandomizedSearchCV

from imblearn.combine import SMOTETomek

import imblearn

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score

# %%
import pandas as pd

# %%
label_encoder = LabelEncoder()

# %%
data = pd.read_csv('/content/drive/MyDrive/data set')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
sns.distplot(data['ApplicantIncome'], color='r')
plt.subplot(122)
sns.distplot(data['Credit_History'])
plt.show()
# Out:
# <ipython-input-76-4b78f43a4171>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['ApplicantIncome'], color='r')
# <ipython-input-76-4b78f43a4171>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Credit_History'])

# %%
plt.figure(figsize=(18, 4))
plt.subplot(1,4,1)
sns.countplot(data=data, x='Gender')
plt.subplot(1,4,2)
sns.countplot(data=data, x='Education')
plt.show()

# %%
plt.figure(figsize=(20, 5))

plt.subplot(131)
sns.countplot(data=data, x='Married', hue='Gender')

plt.subplot(132)
sns.countplot(data=data, x='Self_Employed', hue='Education')

plt.subplot(133)
sns.countplot(data=data, x='Property_Area', hue='Loan_Amount_Term')

plt.show()

# %%
sns.swarmplot(data=data,  x='Gender', y='ApplicantIncome', hue='Loan_Status')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 45.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 70.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 41.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data['Gender'] = data['Gender'].fillna(data['Gender'].mode()[0])

# %%
data['Married'] = data['Married'].fillna(data['Married'].mode()[0])

# %%
data['Dependents'] = data['Dependents'].str.replace('+', '')
# Out:
# <ipython-input-24-d1d049232ac3>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Dependents'] = data['Dependents'].str.replace('+', '')

# %%
data['Dependents'] = data['Dependents'].fillna(data['Dependents'].mode()[0])

# %%
data['Self_Employed'] = data['Self_Employed'].fillna(data['Self_Employed'].mode()[0])

# %%
data['LoanAmount'] = data['LoanAmount'].fillna(data['LoanAmount'].mode()[0])

# %%
data['Loan_Amount_Term'] = data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0])

# %%
data['Credit_History'] = data['Credit_History'].fillna(data['Credit_History'].mode()[0])

# %%
data['Gender'] = data['Gender'].map({'Female':1, 'Male':0})

# %%
data['Property_Area'] = data['Property_Area'].map({'Urban':2, 'Semiurban':1, 'Rural':0})

# %%
data['Married'] = data['Married'].map({'Yes':1, 'No':0})

# %%
data['Education'] = data['Education'].map({'Graduate':1, 'Not Graduate':0})

# %%
data['Loan_Status'] = data['Loan_Status'].map({'Y':1, 'N':0})

# %%
data['Gender']=data['Gender'].astype('int64')
data['Married']=data['Married'].astype('int64')
data['Dependents']=data['Dependents'].astype('int64')
data['Self_Employed'] = data['Self_Employed'].apply(lambda x: 0 if not x.isdigit() else int(x))
data['Coapplicant Income']=data['CoapplicantIncome'].astype('int64')
data['LoanAmount']=data['LoanAmount'].astype('int64')
data['Loan_Amount_Term']=data['Loan_Amount_Term'].astype('int64')
data['Credit_History']=data['Credit_History'].astype('int64')

# %%
from imblearn.combine import SMOTETomek
from collections import Counter
from imblearn.over_sampling import SMOTE
import numpy as np
from sklearn.preprocessing import OneHotEncoder

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loan_ID             614 non-null    object
#  1   Gender              614 non-null    int64
#  2   Married             614 non-null    int64
#  3   Dependents          614 non-null    int64
#  4   Education           614 non-null    int64
#  5   Self_Employed       614 non-null    int64
#  6   ApplicantIncome     614 non-null    int64
#  7   CoapplicantIncome   614 non-null    float64
#  8   LoanAmount          614 non-null    int64
#  9   Loan_Amount_Term    614 non-null    int64
#  10  Credit_History      614 non-null    int64
#  11  Property_Area       614 non-null    int64
#  12  Loan_Status         614 non-null    int64
#  13  Coapplicant Income  614 non-null    int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 67.3+ KB

# %%
data.drop('Loan_ID', axis=1, inplace=True)

# %%
from imblearn.combine import SMOTETomek
smote_tomek = SMOTETomek(sampling_strategy=0.90)

# %%
y=data['Loan_Status']
x = data.drop(columns=['Loan_Status'], axis=1)

# %%
column_names = x.columns
column_names = column_names.tolist()

# %%
x_bal, y_bal = smote_tomek.fit_resample(x, y)

# %%
print(y.value_counts())
print(y_bal.value_counts())
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64
# 1    361
# 0    318
# Name: Loan_Status, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
sc=StandardScaler()
x_bal=sc.fit_transform(x_bal)

# %%
x_bal = pd.DataFrame(x_bal, columns= column_names)

# %%
X_train, X_test, y_train, y_test,  = train_test_split(x_bal, y_bal, test_size=0.33, random_state=42)

# %%
def decisionTree(x_train, x_test, y_train, y_test):
    dt=DecisionTreeClassifier()
    dt.fit(x_train, y_train)
    yPred = dt.predict(x_test)  # You had a space in 'x_test'
    print('*** DecisionTreeClassifier ***')
    print('Confusion matrix')
    print(confusion_matrix(y_test, yPred))
    print('Classification report')
    print(classification_report(y_test, yPred))

# %%
def RandomForest(x_train, x_test, y_train, y_test):
    rf = RandomForestClassifier()
    rf.fit(x_train, y_train)
    yPred = rf.predict(x_test)
    print('*** RandomForestClassifier ***')
    print('Confusion matrix')
    print(confusion_matrix(y_test, yPred))
    print('Classification report')
    print(classification_report(y_test, yPred))

# %%
def KNN(x_train, x_test, y_train, y_test):
    knn = KNeighborsClassifier()
    knn.fit(x_train, y_train)
    yPred = knn.predict(x_test)
    print('***KNeighborsClassifier***')
    print('Confusion matrix')
    print(confusion_matrix(y_test, yPred))
    print('Classification report')
    print(classification_report(y_test, yPred))

# %%
def xgboost(x_train, x_test, y_train, y_test):
    xg = GradientBoostingClassifier()
    xg.fit(x_train, y_train)
    yPred = xg.predict(x_test)
    print('***XGBoost Classifier***')
    print('Confusion matrix')
    print(confusion_matrix(y_test, yPred))
    print('Classification report')
    print(classification_report(y_test, yPred))

# %%
RandomForest(X_train, X_test, y_train, y_test)
# Out:
# *** RandomForestClassifier ***
# Confusion matrix
# [[ 78  29]
#  [ 12 106]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79       107
#            1       0.79      0.90      0.84       118
#
#     accuracy                           0.82       225
#    macro avg       0.83      0.81      0.81       225
# weighted avg       0.82      0.82      0.82       225

# %%
decisionTree(X_train, X_test, y_train, y_test)
# Out:
# *** DecisionTreeClassifier ***
# Confusion matrix
# [[80 27]
#  [24 94]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       107
#            1       0.78      0.80      0.79       118
#
#     accuracy                           0.77       225
#    macro avg       0.77      0.77      0.77       225
# weighted avg       0.77      0.77      0.77       225

# %%
KNN(X_train, X_test, y_train, y_test)
# Out:
# ***KNeighborsClassifier***
# Confusion matrix
# [[ 70  37]
#  [ 14 104]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.83      0.65      0.73       107
#            1       0.74      0.88      0.80       118
#
#     accuracy                           0.77       225
#    macro avg       0.79      0.77      0.77       225
# weighted avg       0.78      0.77      0.77       225

# %%
xgboost(X_train, X_test, y_train, y_test)
# Out:
# ***XGBoost Classifier***
# Confusion matrix
# [[ 71  36]
#  [ 11 107]]
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.87      0.66      0.75       107
#            1       0.75      0.91      0.82       118
#
#     accuracy                           0.79       225
#    macro avg       0.81      0.79      0.79       225
# weighted avg       0.80      0.79      0.79       225

# %%
from sklearn.model_selection import cross_val_score

# %%
# Random forest model is selected
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
yPred = rf.predict(X_test)

# %%
f1_score(yPred,y_test, average='weighted')
# Out:
# 0.8371260608735779

# %%
cv = cross_val_score(rf,x,y,cv=5)

# %%
np.mean(cv)
# Out:
# 0.773583899773424

# %%
import pickle
from sklearn.linear_model import LinearRegression
model = LinearRegression()
with open('rdf.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
pickle.dump(model,open('rdf.pkl','wb'))
